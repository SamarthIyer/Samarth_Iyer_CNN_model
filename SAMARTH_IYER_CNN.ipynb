# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/drive/MyDrive/Cancer Detection/Train")
data_dir_test = pathlib.Path('/content/drive/MyDrive/Cancer Detection/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ###Creating a dataset

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'validation',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %% [markdown]
# ######Printing all class Names

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ###Visualizing the data

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(9):
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ###Creating the model

# %%
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ###Compiling the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      25632
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 32)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 32)        25632
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 64)        51264
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 64)        102464
#
#  max_pooling2d_3 (MaxPoolin  (None, 11, 11, 64)        0
#  g2D)
#
#  dropout (Dropout)           (None, 11, 11, 64)        0
#
#  flatten (Flatten)           (None, 7744)              0
#
#  dense (Dense)               (None, 9)                 69705
#
# =================================================================
# Total params: 277129 (1.06 MB)
# Trainable params: 277129 (1.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 56/56 [==============================] - 395s 1s/step - loss: 2.0565 - accuracy: 0.1908 - val_loss: 2.0454 - val_accuracy: 0.1499
# Epoch 2/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0198 - accuracy: 0.2132 - val_loss: 1.9968 - val_accuracy: 0.2170
# Epoch 3/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.9919 - accuracy: 0.2377 - val_loss: 1.9819 - val_accuracy: 0.2371
# Epoch 4/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0321 - accuracy: 0.2165 - val_loss: 2.1032 - val_accuracy: 0.2036
# Epoch 5/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.1536 - accuracy: 0.2054 - val_loss: 2.0309 - val_accuracy: 0.2058
# Epoch 6/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0253 - accuracy: 0.2048 - val_loss: 2.0256 - val_accuracy: 0.2058
# Epoch 7/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0168 - accuracy: 0.2081 - val_loss: 2.0226 - val_accuracy: 0.1924
# Epoch 8/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0177 - accuracy: 0.1925 - val_loss: 2.0307 - val_accuracy: 0.2081
# Epoch 9/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0409 - accuracy: 0.2070 - val_loss: 2.0484 - val_accuracy: 0.1924
# Epoch 10/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0108 - accuracy: 0.2054 - val_loss: 2.0485 - val_accuracy: 0.2081
# Epoch 11/30
# 56/56 [==============================] - 5s 89ms/step - loss: 2.0102 - accuracy: 0.2031 - val_loss: 2.1011 - val_accuracy: 0.2081
# Epoch 12/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0103 - accuracy: 0.2115 - val_loss: 2.0490 - val_accuracy: 0.2081
# Epoch 13/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0065 - accuracy: 0.2115 - val_loss: 2.0826 - val_accuracy: 0.2058
# Epoch 14/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0037 - accuracy: 0.2143 - val_loss: 2.1163 - val_accuracy: 0.2237
# Epoch 15/30
# 56/56 [==============================] - 5s 87ms/step - loss: 1.9959 - accuracy: 0.2126 - val_loss: 2.0566 - val_accuracy: 0.1969
# Epoch 16/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.9842 - accuracy: 0.2238 - val_loss: 2.1141 - val_accuracy: 0.2327
# Epoch 17/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0302 - accuracy: 0.2176 - val_loss: 2.1773 - val_accuracy: 0.2013
# Epoch 18/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0042 - accuracy: 0.2238 - val_loss: 2.0548 - val_accuracy: 0.2013
# Epoch 19/30
# 56/56 [==============================] - 5s 87ms/step - loss: 1.9920 - accuracy: 0.2171 - val_loss: 2.1026 - val_accuracy: 0.2058
# Epoch 20/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.9788 - accuracy: 0.2372 - val_loss: 2.1332 - val_accuracy: 0.2103
# Epoch 21/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.9685 - accuracy: 0.2394 - val_loss: 2.0560 - val_accuracy: 0.2192
# Epoch 22/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.9228 - accuracy: 0.2656 - val_loss: 2.0555 - val_accuracy: 0.2595
# Epoch 23/30
# 56/56 [==============================] - 5s 87ms/step - loss: 1.8580 - accuracy: 0.2952 - val_loss: 2.1084 - val_accuracy: 0.2953
# Epoch 24/30
# 56/56 [==============================] - 5s 87ms/step - loss: 1.7821 - accuracy: 0.3253 - val_loss: 1.9810 - val_accuracy: 0.2975
# Epoch 25/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.6996 - accuracy: 0.3594 - val_loss: 1.9646 - val_accuracy: 0.3311
# Epoch 26/30
# 56/56 [==============================] - 5s 87ms/step - loss: 1.5973 - accuracy: 0.3984 - val_loss: 2.0330 - val_accuracy: 0.3043
# Epoch 27/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.5178 - accuracy: 0.4408 - val_loss: 2.1443 - val_accuracy: 0.3154
# Epoch 28/30
# 56/56 [==============================] - 5s 88ms/step - loss: 1.4337 - accuracy: 0.4648 - val_loss: 2.2889 - val_accuracy: 0.2640
# Epoch 29/30
# 56/56 [==============================] - 5s 87ms/step - loss: 1.3665 - accuracy: 0.5033 - val_loss: 2.1269 - val_accuracy: 0.3378
# Epoch 30/30
# 56/56 [==============================] - 5s 89ms/step - loss: 1.2343 - accuracy: 0.5552 - val_loss: 2.2441 - val_accuracy: 0.3221

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Finding on the first base model**
#
# - The model is overfitting because we can also see difference in loss functions in training & test around the 10-11th epoch
#
# - The accuracy is just around 75-80% because there are enough features to remember the pattern.
#
# - But again, it's too early to comment on the overfitting & underfitting debate

# %%
data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ####Create the model, compile and train the model

# %%
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ data_augument,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))

])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 10s 126ms/step - loss: 2.0563 - accuracy: 0.1875 - val_loss: 1.9908 - val_accuracy: 0.1924
# Epoch 2/30
# 56/56 [==============================] - 6s 102ms/step - loss: 2.0223 - accuracy: 0.2160 - val_loss: 2.0009 - val_accuracy: 0.2260
# Epoch 3/30
# 56/56 [==============================] - 6s 102ms/step - loss: 2.0230 - accuracy: 0.1998 - val_loss: 2.0162 - val_accuracy: 0.2125
# Epoch 4/30
# 56/56 [==============================] - 6s 102ms/step - loss: 2.0216 - accuracy: 0.2054 - val_loss: 2.0413 - val_accuracy: 0.2058
# Epoch 5/30
# 56/56 [==============================] - 6s 101ms/step - loss: 2.0255 - accuracy: 0.1964 - val_loss: 2.0385 - val_accuracy: 0.2058
# Epoch 6/30
# 56/56 [==============================] - 6s 101ms/step - loss: 2.0144 - accuracy: 0.1987 - val_loss: 2.0496 - val_accuracy: 0.1588
# Epoch 7/30
# 56/56 [==============================] - 6s 102ms/step - loss: 2.0266 - accuracy: 0.2009 - val_loss: 2.0267 - val_accuracy: 0.2058
# Epoch 8/30
# 56/56 [==============================] - 6s 101ms/step - loss: 2.0317 - accuracy: 0.2003 - val_loss: 2.0304 - val_accuracy: 0.2058
# Epoch 9/30
# 56/56 [==============================] - 6s 102ms/step - loss: 2.0292 - accuracy: 0.1864 - val_loss: 2.0322 - val_accuracy: 0.2058
# Epoch 10/30
# 56/56 [==============================] - 6s 100ms/step - loss: 2.0175 - accuracy: 0.1975 - val_loss: 2.1556 - val_accuracy: 0.2148
# Epoch 11/30
# 56/56 [==============================] - 6s 101ms/step - loss: 2.0491 - accuracy: 0.2020 - val_loss: 2.0469 - val_accuracy: 0.1521
# Epoch 12/30
# 56/56 [==============================] - 6s 101ms/step - loss: 2.0785 - accuracy: 0.1936 - val_loss: 2.0215 - val_accuracy: 0.1879
# Epoch 13/30
# 56/56 [==============================] - 6s 102ms/step - loss: 2.0221 - accuracy: 0.2031 - val_loss: 2.0342 - val_accuracy: 0.2058
# Epoch 14/30
# 56/56 [==============================] - 6s 101ms/step - loss: 2.0184 - accuracy: 0.1975 - val_loss: 2.0247 - val_accuracy: 0.2058
# Epoch 15/30
# 56/56 [==============================] - 6s 100ms/step - loss: 2.0162 - accuracy: 0.2015 - val_loss: 2.0292 - val_accuracy: 0.2058
# Epoch 16/30
# 56/56 [==============================] - 6s 102ms/step - loss: 2.0164 - accuracy: 0.1936 - val_loss: 2.0337 - val_accuracy: 0.2036
# Epoch 17/30
# 56/56 [==============================] - 6s 101ms/step - loss: 2.0129 - accuracy: 0.1948 - val_loss: 2.0470 - val_accuracy: 0.2081
# Epoch 18/30
# 56/56 [==============================] - 6s 102ms/step - loss: 2.0137 - accuracy: 0.2054 - val_loss: 2.0250 - val_accuracy: 0.2058
# Epoch 19/30
# 56/56 [==============================] - 6s 100ms/step - loss: 2.0141 - accuracy: 0.1942 - val_loss: 2.0400 - val_accuracy: 0.2036
# Epoch 20/30
# 56/56 [==============================] - 6s 102ms/step - loss: 2.0155 - accuracy: 0.2015 - val_loss: 2.0200 - val_accuracy: 0.2058
# Epoch 21/30
# 56/56 [==============================] - 6s 100ms/step - loss: 2.0149 - accuracy: 0.1964 - val_loss: 2.0173 - val_accuracy: 0.2036
# Epoch 22/30
# 56/56 [==============================] - 6s 101ms/step - loss: 2.0125 - accuracy: 0.1981 - val_loss: 2.0181 - val_accuracy: 0.2013
# Epoch 23/30
# 56/56 [==============================] - 6s 101ms/step - loss: 2.0149 - accuracy: 0.2059 - val_loss: 2.0171 - val_accuracy: 0.2058
# Epoch 24/30
# 56/56 [==============================] - 6s 103ms/step - loss: 2.0092 - accuracy: 0.2115 - val_loss: 2.0156 - val_accuracy: 0.1879
# Epoch 25/30
# 56/56 [==============================] - 6s 101ms/step - loss: 2.0122 - accuracy: 0.1948 - val_loss: 2.0243 - val_accuracy: 0.2103
# Epoch 26/30
# 56/56 [==============================] - 6s 102ms/step - loss: 2.0132 - accuracy: 0.1975 - val_loss: 2.0164 - val_accuracy: 0.2036
# Epoch 27/30
# 56/56 [==============================] - 6s 100ms/step - loss: 2.0087 - accuracy: 0.1992 - val_loss: 2.0176 - val_accuracy: 0.2058
# Epoch 28/30
# 56/56 [==============================] - 6s 102ms/step - loss: 2.0078 - accuracy: 0.2115 - val_loss: 2.0244 - val_accuracy: 0.2081
# Epoch 29/30
# 56/56 [==============================] - 6s 101ms/step - loss: 2.0085 - accuracy: 0.2026 - val_loss: 2.0188 - val_accuracy: 0.2036
# Epoch 30/30
# 56/56 [==============================] - 6s 102ms/step - loss: 2.0073 - accuracy: 0.2104 - val_loss: 2.0175 - val_accuracy: 0.2170

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Finding from Second Model**
#
# - There is no improvement in accuracy but we can definitely see the overfitting problem has solved due to data augmentation
#
# - We can increase the epochs to increase the accuracy so it's too early for judgement

# %%
##
path_list=[]
lesion_list=[]
for i in class_names:

    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 1     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 2     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 3     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 4     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2235  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2236  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2237  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2238  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 1     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 2     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 3     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 4     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2235  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2236  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2237  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2238  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# Answer-1 :- **squamous cell carcinoma** has least number of samples
#
# Answer-2:- **actinic keratosis and dermatofibroma** have proportionate number of classes.
# **melanoma and pigmented benign keratosis** have proprtionate number of classes

# %%
class_names
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.4)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.25.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %%
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline("/content/drive/MyDrive/Cancer Detection/Train",save_format='jpg')
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.

# %% [markdown]
# ######AUGUMENTOR COUNT

# %%
data_dir_train1 = pathlib.Path("/content/drive/MyDrive/Cancer Detection/Train/output")
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)

# %%
##
for i in class_names:

    for j in data_dir_train1.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
new_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
new_df

# %% [markdown]
# Lets see the distribution of augmented data after adding new images to the original training data.

# %%
new_df['Label'].value_counts()

# %% [markdown]
# #### Training the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
import pathlib
#data_dir_train1=pathlib.Path("/content/drive/MyDrive/Cancer Detection/Train/output")
data_dir_train1=pathlib.Path("/content/drive/MyDrive/Cancer Detection/Train")

# %%
data_dir_train1

# %% [markdown]
# ####  Creating a training dataset

# %%
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential


data_dir_train1=pathlib.Path("/content/drive/MyDrive/Cancer Detection/Train")
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %% [markdown]
# ####Creating model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))

])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ####Compiling Model

# %%
## ### Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ####Training Model

# %%
epochs =50
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 169/169 [==============================] - 50s 276ms/step - loss: nan - accuracy: 0.0187 - val_loss: nan - val_accuracy: 0.0230
# Epoch 2/50
# 169/169 [==============================] - 46s 256ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 3/50
# 169/169 [==============================] - 49s 280ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 4/50
# 169/169 [==============================] - 48s 275ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 5/50
# 169/169 [==============================] - 44s 256ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 6/50
# 169/169 [==============================] - 47s 269ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 7/50
# 169/169 [==============================] - 49s 283ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 8/50
# 169/169 [==============================] - 44s 255ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 9/50
# 169/169 [==============================] - 46s 263ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 10/50

# %% [markdown]
# ####Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Observation

# %% [markdown]
# - Accuracy on training data has increased by using Augmentor library
#
# - Model is still overfitting
#
# - The problem of overfitting can be solved by add more layer,neurons or adding dropout layers.
#
# - The Model can be further improved by tuning the hyperparameter
